# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# data from 1st file
# playing around

path = "D:\\Programming\TestData\ex1data1.txt"
data = pd.read_csv(path, header=None, names=['Population', 'Profit'])
data.head()
# Out:
#    Population   Profit
# 0      6.1101  17.5920
# 1      5.5277   9.1302
# 2      8.5186  13.6620
# 3      7.0032  11.8540
# 4      5.8598   6.8233

# %%
data.describe()
# Out:
#        Population     Profit
# count   97.000000  97.000000
# mean     8.159800   5.839135
# std      3.869884   5.510262
# min      5.026900  -2.680700
# 25%      5.707700   1.986900
# 50%      6.589400   4.562300
# 75%      8.578100   7.046700
# max     22.203000  24.147000

# %%
data.plot(kind='scatter', x='Population', y='Profit', figsize=(6,4))

# %%
# data from 2nd file
# will run linear regression on this data

path = "D:\\Programming\TestData\ex1data2.txt"
data = pd.read_csv(path, header=None, names=['Size', 'Bedrooms', 'Price'])
data.head()
# Out:
#    Size  Bedrooms   Price
# 0  2104         3  399900
# 1  1600         3  329900
# 2  2400         3  369000
# 3  1416         2  232000
# 4  3000         4  539900

# %%
# feature normalizing data

#data = (data - data.mean()) / data.std()
#data.head()
# Out:
#        Size  Bedrooms     Price
# 0  0.130010 -0.223675  0.475747
# 1 -0.504190 -0.223675 -0.084074
# 2  0.502476 -0.223675  0.228626
# 3 -0.735723 -1.537767 -0.867025
# 4  1.257476  1.090417  1.595389

# %%
# add intercept term

#data.insert(0, 'Ones', 1)
#data.head()
# Out:
#    Ones      Size  Bedrooms     Price
# 0     1  0.130010 -0.223675  0.475747
# 1     1 -0.504190 -0.223675 -0.084074
# 2     1  0.502476 -0.223675  0.228626
# 3     1 -0.735723 -1.537767 -0.867025
# 4     1  1.257476  1.090417  1.595389

# %%
#extract X,y from data
X = data.iloc[:, :-1]
y = data.iloc[:, -1]

print(X.shape)
print(X[:5])
print('\n')
print(y.shape)
print(y[:5])
# Out:
# (47, 2)
#    Size  Bedrooms
# 0  2104         3
# 1  1600         3
# 2  2400         3
# 3  1416         2
# 4  3000         4
#
#
# (47,)
# 0    399900
# 1    329900
# 2    369000
# 3    232000
# 4    539900
# Name: Price, dtype: int64

# %%
X.shape, y.shape
# Out:
# ((47, 2), (47,))

# %%
# feature normalize X

def featureNormalize(X):

    mu = np.mean(X, axis = 0)
    sigma = np.std(X, axis = 0)
    
    X_norm = (X - mu)/sigma
    
    return (X_norm, mu, sigma)

# %%
# normalize X
print('init X shape = ', X.shape)

X, mu, sigma = featureNormalize(X)

print(X.shape)
print('X = ', X[:5])
# Out:
# init X shape =  (47, 2)
# (47, 2)
# X =         Size  Bedrooms
# 0  0.131415 -0.226093
# 1 -0.509641 -0.226093
# 2  0.507909 -0.226093
# 3 -0.743677 -1.554392
# 4  1.271071  1.102205

# %%
def computeCost(X, y, theta):
    inner = np.power(((X * theta) - y), 2)
    return np.sum(inner) / (2 * len(X))

# %%
# One implementation

def gradientDescent(X, y, theta, alpha, iters):
    temp = np.matrix(np.zeros(theta.shape))
    parameters = int(theta.ravel().shape[1])
    cost = np.zeros(iters)
    
    for i in range(iters):
        error = (X * theta.T) - y
        
        for j in range(parameters):
            term = np.multiply(error, X[:,j])
            temp[0,j] = theta[0,j] - ((alpha / len(X)) * np.sum(term))
            
        theta = temp
        cost[i] = computeCost(X, y, theta)
        
    return theta, cost

# %%
# add intercept term to X i.e. 1's column to X matrix

#TempX = np.insert(X, 0, 1, axis = 1)
#X = TempX

#X = np.insert(X, 0, 1, axis = 1)
X = np.c_[np.ones((X.shape[0], 1)), X]

# adds 1s and retains X as a proper matrix,
# using this method to avoid problems in the matrix multipications within the minimizing function

print(X.shape)
print(X[:5])
# Out:
# (47, 3)
# [[ 1.          0.13141542 -0.22609337]
#  [ 1.         -0.5096407  -0.22609337]
#  [ 1.          0.5079087  -0.22609337]
#  [ 1.         -0.74367706 -1.5543919 ]
#  [ 1.          1.27107075  1.10220517]]

# %%
# converting y to a matrix (m,) => (m,1)
y = y[:, np.newaxis]

print(y.shape)
print(y[:5])
# Out:
# (47, 1)
# [[399900]
#  [329900]
#  [369000]
#  [232000]
#  [539900]]

# %%
# alternate implementation

def GradientDescentMulti(X, y, theta, alpha, num_iters):
    
    # assumptions X is (m x n+1), theta is (n+1 x 1) and y is (mx1)
    # n+1 columns since first column of 1s is added to X matrix of n features
    
    # grad descent -> repeat until convergence...
    # theta_j = theta_j - alpha x 1/m x Sum i(1 to m) [(hypothesis_theta - y)] x Xi  
   
    # X is (m, n+1) - 1s column added to original X
    m = X.shape[0]
    
    # confirm y is desired column vector shape - y should be (m,1) and not (m,)
    y = y.reshape((m,1))
    # confirm theta is desired column vector shape - theta should be (n+1,1) and not (n+1,)
    theta = theta.reshape((X.shape[1],1))
    
    J_history = np.zeros((num_iters, 1))
    
    for iters in range(num_iters):
        
        #H -> hypothesis_theta (m,1), same as y
        H = np.matmul(X, theta)
        
        # say Delta is Sum i(1 to m) of [(hypothesis_theta - y)] x Xi 
        
        # since X is (m, n+1) and [H_theta - y] is (m, 1), X' is (n+1, m)
        # so multiplying X' x [H_theta - y] => (n+1, m) x (m,1) = (n+1,1), same as theta
        
        # the vector multiplication involves sum of products hence no need to
        # use the sum function separately 
        Delta = np.matmul(X.transpose(), H-y) # result Delta is a (n+1, 1) vector, like theta
    
        # simultaneously update all theta values by updating theta array elements
        theta = theta - alpha * 1/m * Delta
        
        # Save the new cost J for new theta from every iteration    
        J_history[iters] = computeCost(X, y, theta)
        
        # print out updated theta values and computed cost for upda theta
        # for every iteration  
        print('Iteration number is: ', iters);
        print("\n")
        print('Updated theta are: ', theta);
        print("\n")
        print('Computed cost J_theta for updated theta is: ', J_history[iters])
 
    
    return theta, J_history

# %%
# initial theta
theta = np.matrix(np.array([0,0,0]))

alpha = 0.1
iters = 1000

# perform linear regression on the data set
# theta, cost = gradientDescent(X, y, theta, alpha, iters) # one call
theta, costHistory = GradientDescentMulti(X, y, theta, alpha, iters)   # alternate call

# get the cost (error) of the model
computeCost(X, y, theta)
# Out:
# Iteration number is:  0
#
#
# Updated theta are:  [[34041.26595745]
#  [10576.41334928]
#  [ 5470.88217559]]
#
#
# Computed cost J_theta for updated theta is:  [5.32682599e+10]
# Iteration number is:  1
#
#
# Updated theta are:  [[64678.40531915]
#  [19788.83390392]
#  [ 9802.4316721 ]]
#
#
# Computed cost J_theta for updated theta is:  [4.33890843e+10]
# Iteration number is:  2
#
#
# Updated theta are:  [[92251.83074468]
#  [27837.4598369 ]
#  [13184.96088065]]
#
#
# Computed cost J_theta for updated theta is:  [3.54574304e+10]
# Iteration number is:  3
#
#
# Updated theta are:  [[117067.91362766]
#  [ 34891.81263413]
#  [ 15778.5405121 ]]
#
#
# Computed cost J_theta for updated theta is:  [2.90805547e+10]
# Iteration number is:  4
#
#
# Updated theta are:  [[139402.38822234]
#  [ 41095.49819809]
#  [ 17717.74155898]]
#
#
# Computed cost J_theta for updated theta is:  [2.39470789e+10]
# Iteration number is:  5
#
#
# Updated theta are:  [[159503.41535755]
#  [ 46570.22630676]
#  [ 19115.63645498]]
#
#
# Computed cost J_theta for updated theta is:  [1.9809573e+10]
# Iteration number is:  6
#
#
# Updated theta are:  [[177594.33977924]
#  [ 51419.20407488]
#  [ 20067.17504203]]
#
#
# Computed cost J_theta for updated theta is:  [1.64710108e+10]
# Iteration number is:  7
#
#
# Updated theta are:  [[193876.17175877]
#  [ 55730.00102595]
#  [ 20652.03291791]]
#
#
# Computed cost J_theta for updated theta is:  [1.37742034e+10]
# Iteration number is:  8
#
#
# Updated theta are:  [[208529.82054034]
#  [ 59576.96815895]
#  [ 20937.01451448]]
#
#
# Computed cost J_theta for updated theta is:  [1.15935242e+10]
# Iteration number is:  9
#
#
# Updated theta are:  [[221718.10444375]
#  [ 63023.28054385]
#  [ 20978.08040833]]
#
#
# Computed cost J_theta for updated theta is:  [9.82841238e+09]
# Iteration number is:  10
#
#
# Updated theta are:  [[233587.55995682]
#  [ 66122.66213488]
#  [ 20822.05752165]]
#
#
# Computed cost J_theta for updated theta is:  [8.398254e+09]
# Iteration number is:  11
#
#
# Updated theta are:  [[244270.06991859]
#  [ 68920.84233678]
#  [ 20508.08171917]]
#
#
# Computed cost J_theta for updated theta is:  [7.23834012e+09]
# Iteration number is:  12
#
#
# Updated theta are:  [[253884.32888417]
#  [ 71456.78613372]
#  [ 20068.81458245]]
#
#
# Computed cost J_theta for updated theta is:  [6.29666589e+09]
# Iteration number is:  13
#
#
# Updated theta are:  [[262537.1619532 ]
#  [ 73763.73307002]
#  [ 19531.46962356]]
#
#
# Computed cost J_theta for updated theta is:  [5.53139023e+09]
# Iteration number is:  14
#
#
# Updated theta are:  [[270324.71171533]
#  [ 75870.07486813]
#  [ 18918.67769792]]
#
#
# Computed cost J_theta for updated theta is:  [4.90881531e+09]
# Iteration number is:  15
#
#
# Updated theta are:  [[277333.50650124]
#  [ 77800.09682457]
#  [ 18249.21673203]]
#
#
# Computed cost J_theta for updated theta is:  [4.4017763e+09]
# Iteration number is:  16
#
#
# Updated theta are:  [[283641.42180857]
#  [ 79574.60420392]
#  [ 17538.62696281]]
#
#
# Computed cost J_theta for updated theta is:  [3.98835592e+09]
# Iteration number is:  17
#
#
# Updated theta are:  [[289318.54558516]
#  [ 81211.45154198]
#  [ 16799.72957688]]
#
#
# Computed cost J_theta for updated theta is:  [3.65085642e+09]
# Iteration number is:  18
#
#
# Updated theta are:  [[294427.95698409]
#  [ 82725.98997658]
#  [ 16043.06384676]]
#
#
# Computed cost J_theta for updated theta is:  [3.37497638e+09]
# Iteration number is:  19
#
#
# Updated theta are:  [[299026.42724313]
#  [ 84131.44536708]
#  [ 15277.25550435]]
#
#
# Computed cost J_theta for updated theta is:  [3.14915057e+09]
# Iteration number is:  20
#
#
# Updated theta are:  [[303165.05047626]
#  [ 85439.23797418]
#  [ 14509.32710359]]
#
#
# Computed cost J_theta for updated theta is:  [2.96401994e+09]
# Iteration number is:  21
#
#
# Updated theta are:  [[306889.81138608]
#  [ 86659.25279254]
#  [ 13744.9594459 ]]
#
#
# Computed cost J_theta for updated theta is:  [2.81200564e+09]
# Iteration number is:  22
#
#
# Updated theta are:  [[310242.09620492]
#  [ 87800.0682111 ]
#  [ 12988.71172528]]
#
#
# Computed cost J_theta for updated theta is:  [2.68696628e+09]
# Iteration number is:  23
#
#
# Updated theta are:  [[313259.15254187]
#  [ 88869.14948   ]
#  [ 12244.20685465]]
#
#
# Computed cost J_theta for updated theta is:  [2.583922e+09]
# Iteration number is:  24
#
#
# Updated theta are:  [[315974.50324513]
#  [ 89873.01245311]
#  [ 11514.28742616]]
#
#
# Computed cost J_theta for updated theta is:  [2.49883199e+09]
# Iteration number is:  25
#
#
# Updated theta are:  [[318418.31887807]
#  [ 90817.36222308]
#  [ 10801.14690625]]
#
#
# Computed cost J_theta for updated theta is:  [2.42841517e+09]
# Iteration number is:  26
#
#
# Updated theta are:  [[320617.75294771]
#  [ 91707.21054638]
#  [ 10106.43994827]]
#
#
# Computed cost J_theta for updated theta is:  [2.37000541e+09]
# Iteration number is:  27
#
#
# Updated theta are:  [[322597.24361038]
#  [ 92546.97534866]
#  [  9431.37509831]]
#
#
# Computed cost J_theta for updated theta is:  [2.32143461e+09]
# Iteration number is:  28
#
#
# Updated theta are:  [[324378.78520679]
#  [ 93340.56508839]
#  [  8776.79265847]]
#
#
# Computed cost J_theta for updated theta is:  [2.28093826e+09]
# Iteration number is:  29
#
#
# Updated theta are:  [[325982.17264356]
#  [ 94091.45032403]
#  [  8143.23003983]]
#
#
# Computed cost J_theta for updated theta is:  [2.24707909e+09]
# Iteration number is:  30
#
#
# Updated theta are:  [[327425.22133665]
#  [ 94802.72446494]
#  [  7530.97657243]]
#
#
# Computed cost J_theta for updated theta is:  [2.21868527e+09]
# Iteration number is:  31
#
#
# Updated theta are:  [[328723.96516043]
#  [ 95477.15537801]
#  [  6940.11943255]]
#
#
# Computed cost J_theta for updated theta is:  [2.19480043e+09]
# Iteration number is:  32
#
#
# Updated theta are:  [[329892.83460184]
#  [ 96117.22926185]
#  [  6370.58208737]]
#
#
# Computed cost J_theta for updated theta is:  [2.17464323e+09]
# Iteration number is:  33
#
#
# Updated theta are:  [[330944.8170991 ]
#  [ 96725.1879808 ]
#  [  5822.15643837]]
#
#
# Computed cost J_theta for updated theta is:  [2.15757453e+09]
# Iteration number is:  34
#
#
# Updated theta are:  [[331891.60134664]
#  [ 97303.0608656 ]
#  [  5294.52965986]]
#
#
# Computed cost J_theta for updated theta is:  [2.14307089e+09]
# Iteration number is:  35
#
#
# Updated theta are:  [[332743.70716942]
#  [ 97852.69183113]
#  [  4787.30657282]]
#
#
# Computed cost J_theta for updated theta is:  [2.13070296e+09]
# Iteration number is:  36
#
#
# Updated theta are:  [[333510.60240992]
#  [ 98375.76252951]
#  [  4300.02826296]]
#
#
# Computed cost J_theta for updated theta is:  [2.12011811e+09]
# Iteration number is:  37
#
#
# Updated theta are:  [[334200.80812638]
#  [ 98873.81214534]
#  [  3832.18754043]]
#
#
# Computed cost J_theta for updated theta is:  [2.11102617e+09]
# Iteration number is:  38
#
#
# Updated theta are:  [[334821.99327119]
#  [ 99348.25434574]
#  [  3383.24174505]]
#
#
# Computed cost J_theta for updated theta is:  [2.10318797e+09]
# Iteration number is:  39
#
#
# Updated theta are:  [[335381.05990152]
#  [ 99800.39181829]
#  [  2952.62332195]]
#
#
# Computed cost J_theta for updated theta is:  [2.09640599e+09]
# Iteration number is:  40
#
#
# Updated theta are:  [[335884.21986881]
#  [100231.42876304]
#  [  2539.74852551]]
#
#
# Computed cost J_theta for updated theta is:  [2.09051677e+09]
# Iteration number is:  41
#
#
# Updated theta are:  [[336337.06383938]
#  [100642.48164786]
#  [  2144.02455343]]
#
#
# Computed cost J_theta for updated theta is:  [2.0853847e+09]
# Iteration number is:  42
#
#
# Updated theta are:  [[336744.62341289]
#  [101034.58848883]
#  [  1764.85536507]]
#
#
# Computed cost J_theta for updated theta is:  [2.08089704e+09]
# Iteration number is:  43
#
#
# Updated theta are:  [[337111.42702904]
#  [101408.71687675]
#  [  1401.6463984 ]]
#
#
# Computed cost J_theta for updated theta is:  [2.07695979e+09]
# Iteration number is:  44
#
#
# Updated theta are:  [[337441.55028359]
#  [101765.77093684]
#  [  1053.80836565]]
#
#
# Computed cost J_theta for updated theta is:  [2.07349437e+09]
# Iteration number is:  45
#
#
# Updated theta are:  [[337738.66121267]
#  [102106.59737999]
#  [   720.7602798 ]]
#
#
# Computed cost J_theta for updated theta is:  [2.0704349e+09]
# Iteration number is:  46
#
#
# Updated theta are:  [[338006.06104885]
#  [102431.99077939]
#  [   401.93183947]]
#
#
# Computed cost J_theta for updated theta is:  [2.06772597e+09]
# Iteration number is:  47
#
#
# Updated theta are:  [[3.38246721e+05]
#  [1.02742698e+05]
#  [9.67652800e+01]]
#
#
# Computed cost J_theta for updated theta is:  [2.06532084e+09]
# Iteration number is:  48
#
#
# Updated theta are:  [[ 3.38463315e+05]
#  [ 1.03039423e+05]
#  [-1.95283219e+02]]
#
#
# Computed cost J_theta for updated theta is:  [2.06317993e+09]
# Iteration number is:  49
#
#
# Updated theta are:  [[338658.2492493 ]
#  [103322.82942954]
#  [  -474.74249522]]
#
#
# Computed cost J_theta for updated theta is:  [2.06126963e+09]
# Iteration number is:  50
#
#
# Updated theta are:  [[338833.69028181]
#  [103593.54385865]
#  [  -742.1256641 ]]
#
#
# Computed cost J_theta for updated theta is:  [2.05956128e+09]
# Iteration number is:  51
#
#
# Updated theta are:  [[338991.58721108]
#  [103852.15942541]
#  [  -997.9296363 ]]
#
#
# Computed cost J_theta for updated theta is:  [2.05803037e+09]
# Iteration number is:  52
#
#
# Updated theta are:  [[339133.69444742]
#  [104099.237619  ]
#  [ -1242.63483487]]
#
#
# Computed cost J_theta for updated theta is:  [2.05665585e+09]
# Iteration number is:  53
#
#
# Updated theta are:  [[339261.59096012]
#  [104335.31068183]
#  [ -1476.70508212]]
#
#
# Computed cost J_theta for updated theta is:  [2.05541957e+09]
# Iteration number is:  54
#
#
# Updated theta are:  [[339376.69782156]
#  [104560.88360458]
#  [ -1700.58762194]]
#
#
# Computed cost J_theta for updated theta is:  [2.05430586e+09]
# Iteration number is:  55
#
#
# Updated theta are:  [[339480.29399685]
#  [104776.43592304]
#  [ -1914.71325167]]
#
#
# Computed cost J_theta for updated theta is:  [2.05330109e+09]
# Iteration number is:  56
#
#
# Updated theta are:  [[339573.53055461]
#  [104982.42334268]
#  [ -2119.49654135]]
#
#
# Computed cost J_theta for updated theta is:  [2.0523934e+09]
# Iteration number is:  57
#
#
# Updated theta are:  [[339657.4434566 ]
#  [105179.27921298]
#  [ -2315.33612201]]
#
#
# Computed cost J_theta for updated theta is:  [2.05157242e+09]
# Iteration number is:  58
#
#
# Updated theta are:  [[339732.96506838]
#  [105367.4158705 ]
#  [ -2502.61502773]]
#
#
# Computed cost J_theta for updated theta is:  [2.05082905e+09]
# Iteration number is:  59
#
#
# Updated theta are:  [[339800.93451899]
#  [105547.22586679]
#  [ -2681.7010787 ]]
#
#
# Computed cost J_theta for updated theta is:  [2.0501553e+09]
# Iteration number is:  60
#
#
# Updated theta are:  [[339862.10702454]
#  [105719.08309499]
#  [ -2852.94729467]]
#
#
# Computed cost J_theta for updated theta is:  [2.0495441e+09]
# Iteration number is:  61
#
#
# Updated theta are:  [[339917.16227953]
#  [105883.34382684]
#  [ -3016.6923302 ]]
#
#
# Computed cost J_theta for updated theta is:  [2.0489892e+09]
# Iteration number is:  62
#
#
# Updated theta are:  [[339966.71200903]
#  [106040.34767049]
#  [ -3173.26092446]]
#
#
# Computed cost J_theta for updated theta is:  [2.04848505e+09]
# Iteration number is:  63
#
#
# Updated theta are:  [[340011.30676557]
#  [106190.41845757]
#  [ -3322.96435963]]
#
#
# Computed cost J_theta for updated theta is:  [2.04802672e+09]
# Iteration number is:  64
#
#
# Updated theta are:  [[340051.44204646]
#  [106333.86506735]
#  [ -3466.10092319]]
#
#
# Computed cost J_theta for updated theta is:  [2.0476098e+09]
# Iteration number is:  65
#
#
# Updated theta are:  [[340087.56379926]
#  [106470.98219429]
#  [ -3602.95637011]]
#
#
# Computed cost J_theta for updated theta is:  [2.04723036e+09]
# Iteration number is:  66
#
#
# Updated theta are:  [[340120.07337678]
#  [106602.05106474]
#  [ -3733.80438175]]
#
#
# Computed cost J_theta for updated theta is:  [2.04688486e+09]
# Iteration number is:  67
#
#
# Updated theta are:  [[340149.33199655]
#  [106727.34010766]
#  [ -3858.90701913]]
#
#
# Computed cost J_theta for updated theta is:  [2.04657015e+09]
# Iteration number is:  68
#
#
# Updated theta are:  [[340175.66475434]
#  [106847.10558371]
#  [ -3978.51516828]]
#
#
# Computed cost J_theta for updated theta is:  [2.04628336e+09]
# Iteration number is:  69
#
#
# Updated theta are:  [[340199.36423635]
#  [106961.59217624]
#  [ -4092.86897639]]
#
#
# Computed cost J_theta for updated theta is:  [2.04602195e+09]
# Iteration number is:  70
#
#
# Updated theta are:  [[340220.69377017]
#  [107071.03354774]
#  [ -4202.19827741]]
#
#
# Computed cost J_theta for updated theta is:  [2.04578359e+09]
# Iteration number is:  71
#
#
# Updated theta are:  [[340239.8903506 ]
#  [107175.65286439]
#  [ -4306.72300621]]
#
#
# Computed cost J_theta for updated theta is:  [2.04556619e+09]
# Iteration number is:  72
#
#
# Updated theta are:  [[340257.16727298]
#  [107275.6632914 ]
#  [ -4406.65360076]]
#
#
# Computed cost J_theta for updated theta is:  [2.04536787e+09]
# Iteration number is:  73
#
#
# Updated theta are:  [[340272.71650313]
#  [107371.26846127]
#  [ -4502.19139177]]
#
#
# Computed cost J_theta for updated theta is:  [2.04518692e+09]
# Iteration number is:  74
#
#
# Updated theta are:  [[340286.71081027]
#  [107462.66291713]
#  [ -4593.52897965]]
#
#
# Computed cost J_theta for updated theta is:  [2.04502177e+09]
# Iteration number is:  75
#
#
# Updated theta are:  [[340299.30568669]
#  [107550.03253278]
#  [ -4680.85059854]]
#
#
# Computed cost J_theta for updated theta is:  [2.04487104e+09]
# Iteration number is:  76
#
#
# Updated theta are:  [[340310.64107546]
#  [107633.55491114]
#  [ -4764.33246748]]
#
#
# Computed cost J_theta for updated theta is:  [2.04473344e+09]
# Iteration number is:  77
#
#
# Updated theta are:  [[340320.84292536]
#  [107713.39976254]
#  [ -4844.1431288 ]]
#
#
# Computed cost J_theta for updated theta is:  [2.0446078e+09]
# Iteration number is:  78
#
#
# Updated theta are:  [[340330.02459027]
#  [107789.72926409]
#  [ -4920.4437738 ]]
#
#
# Computed cost J_theta for updated theta is:  [2.04449308e+09]
# Iteration number is:  79
#
#
# Updated theta are:  [[340338.28808869]
#  [107862.69840138]
#  [ -4993.38855607]]
#
#
# Computed cost J_theta for updated theta is:  [2.04438832e+09]
# Iteration number is:  80
#
#
# Updated theta are:  [[340345.72523727]
#  [107932.45529351]
#  [ -5063.12489249]]
#
#
# Computed cost J_theta for updated theta is:  [2.04429265e+09]
# Iteration number is:  81
#
#
# Updated theta are:  [[340352.41867099]
#  [107999.14150257]
#  [ -5129.79375246]]
#
#
# Computed cost J_theta for updated theta is:  [2.04420526e+09]
# Iteration number is:  82
#
#
# Updated theta are:  [[340358.44276134]
#  [108062.89232823]
#  [ -5193.52993543]]
#
#
# Computed cost J_theta for updated theta is:  [2.04412544e+09]
# Iteration number is:  83
#
#
# Updated theta are:  [[340363.86444265]
#  [108123.83708855]
#  [ -5254.46233727]]
#
#
# Computed cost J_theta for updated theta is:  [2.04405252e+09]
# Iteration number is:  84
#
#
# Updated theta are:  [[340368.74395583]
#  [108182.09938751]
#  [ -5312.71420563]]
#
#
# Computed cost J_theta for updated theta is:  [2.04398591e+09]
# Iteration number is:  85
#
#
# Updated theta are:  [[340373.1355177 ]
#  [108237.79737016]
#  [ -5368.40338482]]
#
#
# Computed cost J_theta for updated theta is:  [2.04392506e+09]
# Iteration number is:  86
#
#
# Updated theta are:  [[340377.08792337]
#  [108291.04396594]
#  [ -5421.64255046]]
#
#
# Computed cost J_theta for updated theta is:  [2.04386946e+09]
# Iteration number is:  87
#
#
# Updated theta are:  [[340380.64508848]
#  [108341.94712081]
#  [ -5472.53943427]]
#
#
# Computed cost J_theta for updated theta is:  [2.04381866e+09]
# Iteration number is:  88
#
#
# Updated theta are:  [[340383.84653708]
#  [108390.61001878]
#  [ -5521.19703943]]
#
#
# Computed cost J_theta for updated theta is:  [2.04377225e+09]
# Iteration number is:  89
#
#
# Updated theta are:  [[340386.72784082]
#  [108437.13129326]
#  [ -5567.71384677]]
#
#
# Computed cost J_theta for updated theta is:  [2.04372984e+09]
# Iteration number is:  90
#
#
# Updated theta are:  [[340389.32101419]
#  [108481.60522895]
#  [ -5612.18401217]]
#
#
# Computed cost J_theta for updated theta is:  [2.0436911e+09]
# Iteration number is:  91
#
#
# Updated theta are:  [[340391.65487021]
#  [108524.12195449]
#  [ -5654.69755558]]
#
#
# Computed cost J_theta for updated theta is:  [2.04365569e+09]
# Iteration number is:  92
#
#
# Updated theta are:  [[340393.75534064]
#  [108564.76762648]
#  [ -5695.34054184]]
#
#
# Computed cost J_theta for updated theta is:  [2.04362333e+09]
# Iteration number is:  93
#
#
# Updated theta are:  [[340395.64576402]
#  [108603.62460521]
#  [ -5734.19525381]]
#
#
# Computed cost J_theta for updated theta is:  [2.04359377e+09]
# Iteration number is:  94
#
#
# Updated theta are:  [[340397.34714507]
#  [108640.77162251]
#  [ -5771.34035795]]
#
#
# Computed cost J_theta for updated theta is:  [2.04356675e+09]
# Iteration number is:  95
#
#
# Updated theta are:  [[340398.87838801]
#  [108676.28394209]
#  [ -5806.85106282]]
#
#
# Computed cost J_theta for updated theta is:  [2.04354206e+09]
# Iteration number is:  96
#
#
# Updated theta are:  [[340400.25650665]
#  [108710.23351273]
#  [ -5840.79927064]]
#
#
# Computed cost J_theta for updated theta is:  [2.0435195e+09]
# Iteration number is:  97
#
#
# Updated theta are:  [[340401.49681343]
#  [108742.68911461]
#  [ -5873.25372229]]
#
#
# Computed cost J_theta for updated theta is:  [2.04349888e+09]
# Iteration number is:  98
#
#
# Updated theta are:  [[340402.61308954]
#  [108773.71649915]
#  [ -5904.28013604]]
#
#
# Computed cost J_theta for updated theta is:  [2.04348004e+09]
# Iteration number is:  99
#
#
# Updated theta are:  [[340403.61773803]
#  [108803.37852266]
#  [ -5933.9413402 ]]
#
#
# Computed cost J_theta for updated theta is:  [2.04346282e+09]
# Iteration number is:  100
#
#
# Updated theta are:  [[340404.52192167]
#  [108831.73527397]
#  [ -5962.29739997]]
#
#
# Computed cost J_theta for updated theta is:  [2.04344709e+09]
# Iteration number is:  101
#
#
# Updated theta are:  [[340405.33568695]
#  [108858.8441965 ]
#  [ -5989.40573885]]
#
#
# Computed cost J_theta for updated theta is:  [2.04343271e+09]
# Iteration number is:  102
#
#
# Updated theta are:  [[340406.06807571]
#  [108884.76020486]
#  [ -6015.32125459]]
#
#
# Computed cost J_theta for updated theta is:  [2.04341957e+09]
# Iteration number is:  103
#
#
# Updated theta are:  [[340406.72722558]
#  [108909.53579627]
#  [ -6040.09643024]]
#
#
# Computed cost J_theta for updated theta is:  [2.04340756e+09]
# Iteration number is:  104
#
#
# Updated theta are:  [[340407.32046047]
#  [108933.22115712]
#  [ -6063.78144018]]
#
#
# Computed cost J_theta for updated theta is:  [2.04339658e+09]
# Iteration number is:  105
#
#
# Updated theta are:  [[340407.85437187]
#  [108955.86426477]
#  [ -6086.42425166]]
#
#
# Computed cost J_theta for updated theta is:  [2.04338655e+09]
# Iteration number is:  106
#
#
# Updated theta are:  [[340408.33489213]
#  [108977.51098483]
#  [ -6108.07072176]]
#
#
# Computed cost J_theta for updated theta is:  [2.04337738e+09]
# Iteration number is:  107
#
#
# Updated theta are:  [[340408.76736036]
#  [108998.20516423]
#  [ -6128.76469019]]
#
#
# Computed cost J_theta for updated theta is:  [2.043369e+09]
# Iteration number is:  108
#
#
# Updated theta are:  [[340409.15658177]
#  [109017.98872005]
#  [ -6148.54806794]]
#
#
# Computed cost J_theta for updated theta is:  [2.04336135e+09]
# Iteration number is:  109
#
#
# Updated theta are:  [[340409.50688104]
#  [109036.90172456]
#  [ -6167.46092217]]
#
#
# Computed cost J_theta for updated theta is:  [2.04335435e+09]
# Iteration number is:  110
#
#
# Updated theta are:  [[340409.82215039]
#  [109054.98248643]
#  [ -6185.5415572 ]]
#
#
# Computed cost J_theta for updated theta is:  [2.04334795e+09]
# Iteration number is:  111
#
#
# Updated theta are:  [[340410.10589279]
#  [109072.26762838]
#  [ -6202.8265921 ]]
#
#
# Computed cost J_theta for updated theta is:  [2.04334211e+09]
# Iteration number is:  112
#
#
# Updated theta are:  [[340410.36126096]
#  [109088.7921614 ]
#  [ -6219.35103477]]
#
#
# Computed cost J_theta for updated theta is:  [2.04333677e+09]
# Iteration number is:  113
#
#
# Updated theta are:  [[340410.59109231]
#  [109104.58955571]
#  [ -6235.14835282]]
#
#
# Computed cost J_theta for updated theta is:  [2.04333188e+09]
# Iteration number is:  114
#
#
# Updated theta are:  [[340410.79794053]
#  [109119.6918086 ]
#  [ -6250.25054135]]
#
#
# Computed cost J_theta for updated theta is:  [2.04332742e+09]
# Iteration number is:  115
#
#
# Updated theta are:  [[340410.98410392]
#  [109134.12950923]
#  [ -6264.68818765]]
#
#
# Computed cost J_theta for updated theta is:  [2.04332335e+09]
# Iteration number is:  116
#
#
# Updated theta are:  [[340411.15165098]
#  [109147.93190063]
#  [ -6278.49053321]]
#
#
# Computed cost J_theta for updated theta is:  [2.04331962e+09]
# Iteration number is:  117
#
#
# Updated theta are:  [[340411.30244333]
#  [109161.12693899]
#  [ -6291.68553287]]
#
#
# Computed cost J_theta for updated theta is:  [2.04331621e+09]
# Iteration number is:  118
#
#
# Updated theta are:  [[340411.43815644]
#  [109173.74135021]
#  [ -6304.29991143]]
#
#
# Computed cost J_theta for updated theta is:  [2.0433131e+09]
# Iteration number is:  119
#
#
# Updated theta are:  [[340411.56029824]
#  [109185.80068414]
#  [ -6316.3592178 ]]
#
#
# Computed cost J_theta for updated theta is:  [2.04331026e+09]
# Iteration number is:  120
#
#
# Updated theta are:  [[340411.67022587]
#  [109197.32936629]
#  [ -6327.88787668]]
#
#
# Computed cost J_theta for updated theta is:  [2.04330766e+09]
# Iteration number is:  121
#
#
# Updated theta are:  [[340411.76916073]
#  [109208.35074731]
#  [ -6338.90923806]]
#
#
# Computed cost J_theta for updated theta is:  [2.04330528e+09]
# Iteration number is:  122
#
#
# Updated theta are:  [[340411.8582021 ]
#  [109218.88715032]
#  [ -6349.4456245 ]]
#
#
# Computed cost J_theta for updated theta is:  [2.04330311e+09]
# Iteration number is:  123
#
#
# Updated theta are:  [[340411.93833934]
#  [109228.95991611]
#  [ -6359.51837631]]
#
#
# Computed cost J_theta for updated theta is:  [2.04330112e+09]
# Iteration number is:  124
#
#
# Updated theta are:  [[340412.01046285]
#  [109238.58944639]
#  [ -6369.14789478]]
#
#
# Computed cost J_theta for updated theta is:  [2.04329931e+09]
# Iteration number is:  125
#
#
# Updated theta are:  [[340412.07537401]
#  [109247.7952451 ]
#  [ -6378.35368353]]
#
#
# Computed cost J_theta for updated theta is:  [2.04329765e+09]
# Iteration number is:  126
#
#
# Updated theta are:  [[340412.13379406]
#  [109256.59595792]
#  [ -6387.15438793]]
#
#
# Computed cost J_theta for updated theta is:  [2.04329614e+09]
# Iteration number is:  127
#
#
# Updated theta are:  [[340412.1863721 ]
#  [109265.00941003]
#  [ -6395.56783295]]
#
#
# Computed cost J_theta for updated theta is:  [2.04329475e+09]
# Iteration number is:  128
#
#
# Updated theta are:  [[340412.23369234]
#  [109273.05264227]
#  [ -6403.6110592 ]]
#
#
# Computed cost J_theta for updated theta is:  [2.04329349e+09]
# Iteration number is:  129
#
#
# Updated theta are:  [[340412.27628055]
#  [109280.74194557]
#  [ -6411.30035745]]
#
#
# Computed cost J_theta for updated theta is:  [2.04329233e+09]
# Iteration number is:  130
#
#
# Updated theta are:  [[340412.31460994]
#  [109288.09289403]
#  [ -6418.65130164]]
#
#
# Computed cost J_theta for updated theta is:  [2.04329127e+09]
# Iteration number is:  131
#
#
# Updated theta are:  [[340412.34910639]
#  [109295.12037641]
#  [ -6425.67878041]]
#
#
# Computed cost J_theta for updated theta is:  [2.04329031e+09]
# Iteration number is:  132
#
#
# Updated theta are:  [[340412.3801532 ]
#  [109301.83862631]
#  [ -6432.39702728]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328942e+09]
# Iteration number is:  133
#
#
# Updated theta are:  [[340412.40809533]
#  [109308.26125102]
#  [ -6438.81964942]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328862e+09]
# Iteration number is:  134
#
#
# Updated theta are:  [[340412.43324324]
#  [109314.40125903]
#  [ -6444.95965527]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328788e+09]
# Iteration number is:  135
#
#
# Updated theta are:  [[340412.45587636]
#  [109320.27108643]
#  [ -6450.82948084]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328721e+09]
# Iteration number is:  136
#
#
# Updated theta are:  [[340412.47624617]
#  [109325.88262207]
#  [ -6456.44101494]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328659e+09]
# Iteration number is:  137
#
#
# Updated theta are:  [[340412.494579  ]
#  [109331.24723166]
#  [ -6461.80562322]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328603e+09]
# Iteration number is:  138
#
#
# Updated theta are:  [[340412.51107855]
#  [109336.37578076]
#  [ -6466.93417122]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328551e+09]
# Iteration number is:  139
#
#
# Updated theta are:  [[340412.52592814]
#  [109341.27865681]
#  [ -6471.83704635]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328504e+09]
# Iteration number is:  140
#
#
# Updated theta are:  [[340412.53929277]
#  [109345.96579019]
#  [ -6476.52417894]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328461e+09]
# Iteration number is:  141
#
#
# Updated theta are:  [[340412.55132094]
#  [109350.44667428]
#  [ -6481.00506238]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328422e+09]
# Iteration number is:  142
#
#
# Updated theta are:  [[340412.5621463 ]
#  [109354.73038474]
#  [ -6485.28877228]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328386e+09]
# Iteration number is:  143
#
#
# Updated theta are:  [[340412.57188911]
#  [109358.82559786]
#  [ -6489.38398493]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328353e+09]
# Iteration number is:  144
#
#
# Updated theta are:  [[340412.58065765]
#  [109362.74060815]
#  [ -6493.29899482]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328323e+09]
# Iteration number is:  145
#
#
# Updated theta are:  [[340412.58854933]
#  [109366.48334512]
#  [ -6497.04173146]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328296e+09]
# Iteration number is:  146
#
#
# Updated theta are:  [[340412.59565184]
#  [109370.06138938]
#  [ -6500.61977543]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328271e+09]
# Iteration number is:  147
#
#
# Updated theta are:  [[340412.60204411]
#  [109373.48198793]
#  [ -6504.04037374]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328248e+09]
# Iteration number is:  148
# Updated theta are:  [[340412.60779714]
#  [109376.75206892]
#  [ -6507.31045453]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328227e+09]
# Iteration number is:  149
#
#
# Updated theta are:  [[340412.61297488]
#  [109379.8782556 ]
#  [ -6510.43664104]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328208e+09]
# Iteration number is:  150
#
#
# Updated theta are:  [[340412.61763483]
#  [109382.86687982]
#  [ -6513.42526511]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328191e+09]
# Iteration number is:  151
#
#
# Updated theta are:  [[340412.6218288 ]
#  [109385.72399475]
#  [ -6516.28237993]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328175e+09]
# Iteration number is:  152
#
#
# Updated theta are:  [[340412.62560337]
#  [109388.45538726]
#  [ -6519.01377233]]
#
#
# Computed cost J_theta for updated theta is:  [2.0432816e+09]
# Iteration number is:  153
#
#
# Updated theta are:  [[340412.62900048]
#  [109391.06658952]
#  [ -6521.62497451]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328147e+09]
# Iteration number is:  154
#
#
# Updated theta are:  [[340412.63205787]
#  [109393.56289033]
#  [ -6524.12127524]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328134e+09]
# Iteration number is:  155
#
#
# Updated theta are:  [[340412.63480953]
#  [109395.9493457 ]
#  [ -6526.50773055]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328123e+09]
# Iteration number is:  156
#
#
# Updated theta are:  [[340412.63728603]
#  [109398.23078921]
#  [ -6528.78917401]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328113e+09]
# Iteration number is:  157
#
#
# Updated theta are:  [[340412.63951487]
#  [109400.41184172]
#  [ -6530.97022647]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328104e+09]
# Iteration number is:  158
#
#
# Updated theta are:  [[340412.64152083]
#  [109402.49692076]
#  [ -6533.05530548]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328095e+09]
# Iteration number is:  159
#
#
# Updated theta are:  [[340412.64332619]
#  [109404.49024948]
#  [ -6535.04863417]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328088e+09]
# Iteration number is:  160
#
#
# Updated theta are:  [[340412.64495102]
#  [109406.39586521]
#  [ -6536.95424987]]
#
#
# Computed cost J_theta for updated theta is:  [2.0432808e+09]
# Iteration number is:  161
#
#
# Updated theta are:  [[340412.64641337]
#  [109408.21762759]
#  [ -6538.77601223]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328074e+09]
# Iteration number is:  162
#
#
# Updated theta are:  [[340412.64772948]
#  [109409.95922644]
#  [ -6540.51761107]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328068e+09]
# Iteration number is:  163
#
#
# Updated theta are:  [[340412.64891398]
#  [109411.62418924]
#  [ -6542.18257385]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328063e+09]
# Iteration number is:  164
#
#
# Updated theta are:  [[340412.64998003]
#  [109413.21588821]
#  [ -6543.7742728 ]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328058e+09]
# Iteration number is:  165
#
#
# Updated theta are:  [[340412.65093947]
#  [109414.73754721]
#  [ -6545.29593179]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328053e+09]
# Iteration number is:  166
#
#
# Updated theta are:  [[340412.65180297]
#  [109416.19224822]
#  [ -6546.75063279]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328049e+09]
# Iteration number is:  167
#
#
# Updated theta are:  [[340412.65258012]
#  [109417.58293761]
#  [ -6548.14132217]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328045e+09]
# Iteration number is:  168
#
#
# Updated theta are:  [[340412.65327955]
#  [109418.91243211]
#  [ -6549.47081667]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328042e+09]
# Iteration number is:  169
#
#
# Updated theta are:  [[340412.65390905]
#  [109420.18342449]
#  [ -6550.74180904]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328039e+09]
# Iteration number is:  170
#
#
# Updated theta are:  [[340412.65447559]
#  [109421.39848904]
#  [ -6551.95687358]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328036e+09]
# Iteration number is:  171
#
#
# Updated theta are:  [[340412.65498548]
#  [109422.56008676]
#  [ -6553.1184713 ]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328033e+09]
# Iteration number is:  172
#
#
# Updated theta are:  [[340412.65544438]
#  [109423.67057037]
#  [ -6554.22895491]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328031e+09]
# Iteration number is:  173
#
#
# Updated theta are:  [[340412.65585738]
#  [109424.73218906]
#  [ -6555.2905736 ]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328028e+09]
# Iteration number is:  174
#
#
# Updated theta are:  [[340412.65622909]
#  [109425.74709305]
#  [ -6556.30547758]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328026e+09]
# Iteration number is:  175
#
#
# Updated theta are:  [[340412.65656363]
#  [109426.71733793]
#  [ -6557.27572247]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328025e+09]
# Iteration number is:  176
#
#
# Updated theta are:  [[340412.65686471]
#  [109427.64488886]
#  [ -6558.20327339]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328023e+09]
# Iteration number is:  177
#
#
# Updated theta are:  [[340412.65713569]
#  [109428.5316245 ]
#  [ -6559.09000903]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328021e+09]
# Iteration number is:  178
#
#
# Updated theta are:  [[340412.65737957]
#  [109429.37934087]
#  [ -6559.9377254 ]]
#
#
# Computed cost J_theta for updated theta is:  [2.0432802e+09]
# Iteration number is:  179
#
#
# Updated theta are:  [[340412.65759906]
#  [109430.18975494]
#  [ -6560.74813946]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328019e+09]
# Iteration number is:  180
#
#
# Updated theta are:  [[340412.6577966 ]
#  [109430.96450813]
#  [ -6561.52289265]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328018e+09]
# Iteration number is:  181
#
#
# Updated theta are:  [[340412.65797439]
#  [109431.70516964]
#  [ -6562.26355416]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328016e+09]
# Iteration number is:  182
#
#
# Updated theta are:  [[340412.65813439]
#  [109432.41323961]
#  [ -6562.97162413]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328015e+09]
# Iteration number is:  183
#
#
# Updated theta are:  [[340412.6582784 ]
#  [109433.09015218]
#  [ -6563.6485367 ]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328015e+09]
# Iteration number is:  184
#
#
# Updated theta are:  [[340412.65840801]
#  [109433.73727838]
#  [ -6564.2956629 ]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328014e+09]
# Iteration number is:  185
#
#
# Updated theta are:  [[340412.65852465]
#  [109434.3559289 ]
#  [ -6564.91431342]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328013e+09]
# Iteration number is:  186
#
#
# Updated theta are:  [[340412.65862964]
#  [109434.94735677]
#  [ -6565.5057413 ]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328012e+09]
# Iteration number is:  187
#
#
# Updated theta are:  [[340412.65872412]
#  [109435.51275988]
#  [ -6566.0711444 ]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328012e+09]
# Iteration number is:  188
#
#
# Updated theta are:  [[340412.65880915]
#  [109436.0532834 ]
#  [ -6566.61166792]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328011e+09]
# Iteration number is:  189
#
#
# Updated theta are:  [[340412.65888568]
#  [109436.5700221 ]
#  [ -6567.12840662]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328011e+09]
# Iteration number is:  190
#
#
# Updated theta are:  [[340412.65895456]
#  [109437.06402261]
#  [ -6567.62240713]]
#
#
# Computed cost J_theta for updated theta is:  [2.0432801e+09]
# Iteration number is:  191
#
#
# Updated theta are:  [[340412.65901655]
#  [109437.53628548]
#  [ -6568.09467   ]]
#
#
# Computed cost J_theta for updated theta is:  [2.0432801e+09]
# Iteration number is:  192
#
#
# Updated theta are:  [[340412.65907235]
#  [109437.98776723]
#  [ -6568.54615175]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328009e+09]
# Iteration number is:  193
#
#
# Updated theta are:  [[340412.65912256]
#  [109438.41938231]
#  [ -6568.97776683]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328009e+09]
# Iteration number is:  194
#
#
# Updated theta are:  [[340412.65916775]
#  [109438.8320049 ]
#  [ -6569.39038942]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328009e+09]
# Iteration number is:  195
#
#
# Updated theta are:  [[340412.65920842]
#  [109439.22647075]
#  [ -6569.78485527]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328008e+09]
# Iteration number is:  196
#
#
# Updated theta are:  [[340412.65924503]
#  [109439.60357881]
#  [ -6570.16196333]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328008e+09]
# Iteration number is:  197
#
#
# Updated theta are:  [[340412.65927797]
#  [109439.96409287]
#  [ -6570.52247739]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328008e+09]
# Iteration number is:  198
#
#
# Updated theta are:  [[340412.65930762]
#  [109440.30874314]
#  [ -6570.86712766]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328008e+09]
# Iteration number is:  199
#
#
# Updated theta are:  [[340412.6593343 ]
#  [109440.63822766]
#  [ -6571.19661218]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328007e+09]
# Iteration number is:  200
#
#
# Updated theta are:  [[340412.65935832]
#  [109440.95321378]
#  [ -6571.5115983 ]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328007e+09]
# Iteration number is:  201
#
#
# Updated theta are:  [[340412.65937994]
#  [109441.25433948]
#  [ -6571.812724  ]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328007e+09]
# Iteration number is:  202
#
#
# Updated theta are:  [[340412.65939939]
#  [109441.54221467]
#  [ -6572.10059919]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328007e+09]
# Iteration number is:  203
#
#
# Updated theta are:  [[340412.6594169 ]
#  [109441.8174224 ]
#  [ -6572.37580692]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328007e+09]
# Iteration number is:  204
#
#
# Updated theta are:  [[340412.65943265]
#  [109442.08052008]
#  [ -6572.6389046 ]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328006e+09]
# Iteration number is:  205
#
#
# Updated theta are:  [[340412.65944684]
#  [109442.33204061]
#  [ -6572.89042513]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328006e+09]
# Iteration number is:  206
#
#
# Updated theta are:  [[340412.6594596 ]
#  [109442.57249341]
#  [ -6573.13087793]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328006e+09]
# Iteration number is:  207
#
#
# Updated theta are:  [[340412.65947109]
#  [109442.8023655 ]
#  [ -6573.36075001]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328006e+09]
# Iteration number is:  208
#
#
# Updated theta are:  [[340412.65948142]
#  [109443.02212246]
#  [ -6573.58050698]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328006e+09]
# Iteration number is:  209
#
#
# Updated theta are:  [[340412.65949073]
#  [109443.23220939]
#  [ -6573.79059391]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328006e+09]
# Iteration number is:  210
#
#
# Updated theta are:  [[340412.6594991 ]
#  [109443.43305181]
#  [ -6573.99143633]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328006e+09]
# Iteration number is:  211
#
#
# Updated theta are:  [[340412.65950664]
#  [109443.6250565 ]
#  [ -6574.18344102]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328006e+09]
# Iteration number is:  212
#
#
# Updated theta are:  [[340412.65951342]
#  [109443.80861236]
#  [ -6574.36699688]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328006e+09]
# Iteration number is:  213
#
#
# Updated theta are:  [[340412.65951953]
#  [109443.98409116]
#  [ -6574.54247568]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328006e+09]
# Iteration number is:  214
#
#
# Updated theta are:  [[340412.65952502]
#  [109444.15184832]
#  [ -6574.71023284]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328006e+09]
# Iteration number is:  215
#
#
# Updated theta are:  [[340412.65952997]
#  [109444.31222361]
#  [ -6574.87060813]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328006e+09]
# Iteration number is:  216
#
#
# Updated theta are:  [[340412.65953442]
#  [109444.46554186]
#  [ -6575.02392638]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328006e+09]
# Iteration number is:  217
#
#
# Updated theta are:  [[340412.65953842]
#  [109444.61211361]
#  [ -6575.17049813]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328006e+09]
# Iteration number is:  218
#
#
# Updated theta are:  [[340412.65954203]
#  [109444.75223572]
#  [ -6575.31062024]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328005e+09]
# Iteration number is:  219
#
#
# Updated theta are:  [[340412.65954527]
#  [109444.88619199]
#  [ -6575.44457651]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328005e+09]
# Iteration number is:  220
#
#
# Updated theta are:  [[340412.65954819]
#  [109445.01425375]
#  [ -6575.57263827]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328005e+09]
# Iteration number is:  221
#
#
# Updated theta are:  [[340412.65955082]
#  [109445.13668038]
#  [ -6575.6950649 ]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328005e+09]
# Iteration number is:  222
#
#
# Updated theta are:  [[340412.65955318]
#  [109445.25371983]
#  [ -6575.81210435]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328005e+09]
# Iteration number is:  223
#
#
# Updated theta are:  [[340412.65955531]
#  [109445.36560916]
#  [ -6575.92399368]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328005e+09]
# Iteration number is:  224
#
#
# Updated theta are:  [[340412.65955723]
#  [109445.47257499]
#  [ -6576.03095951]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328005e+09]
# Iteration number is:  225
#
#
# Updated theta are:  [[340412.65955895]
#  [109445.57483398]
#  [ -6576.1332185 ]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328005e+09]
# Iteration number is:  226
#
#
# Updated theta are:  [[340412.6595605 ]
#  [109445.67259323]
#  [ -6576.23097775]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328005e+09]
# Iteration number is:  227
#
#
# Updated theta are:  [[340412.6595619 ]
#  [109445.76605076]
#  [ -6576.32443528]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328005e+09]
# Iteration number is:  228
#
#
# Updated theta are:  [[340412.65956316]
#  [109445.85539585]
#  [ -6576.41378037]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328005e+09]
# Iteration number is:  229
#
#
# Updated theta are:  [[340412.65956429]
#  [109445.94080946]
#  [ -6576.49919398]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328005e+09]
# Iteration number is:  230
#
#
# Updated theta are:  [[340412.65956531]
#  [109446.0224646 ]
#  [ -6576.58084912]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328005e+09]
# Iteration number is:  231
#
#
# Updated theta are:  [[340412.65956622]
#  [109446.10052664]
#  [ -6576.65891116]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328005e+09]
# Iteration number is:  232
#
#
# Updated theta are:  [[340412.65956705]
#  [109446.17515369]
#  [ -6576.73353821]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328005e+09]
# Iteration number is:  233
#
#
# Updated theta are:  [[340412.65956779]
#  [109446.24649691]
#  [ -6576.80488143]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328005e+09]
# Iteration number is:  234
#
#
# Updated theta are:  [[340412.65956846]
#  [109446.31470079]
#  [ -6576.87308531]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328005e+09]
# Iteration number is:  235
#
#
# Updated theta are:  [[340412.65956906]
#  [109446.37990348]
#  [ -6576.938288  ]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328005e+09]
# Iteration number is:  236
#
#
# Updated theta are:  [[340412.6595696 ]
#  [109446.44223704]
#  [ -6577.00062156]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328005e+09]
# Iteration number is:  237
#
#
# Updated theta are:  [[340412.65957009]
#  [109446.50182771]
#  [ -6577.06021223]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328005e+09]
# Iteration number is:  238
#
#
# Updated theta are:  [[340412.65957052]
#  [109446.55879621]
#  [ -6577.11718072]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328005e+09]
# Iteration number is:  239
#
#
# Updated theta are:  [[340412.65957092]
#  [109446.6132579 ]
#  [ -6577.17164242]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328005e+09]
# Iteration number is:  240
#
#
# Updated theta are:  [[340412.65957127]
#  [109446.66532309]
#  [ -6577.22370761]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328005e+09]
# Iteration number is:  241
#
#
# Updated theta are:  [[340412.65957159]
#  [109446.71509725]
#  [ -6577.27348177]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328005e+09]
# Iteration number is:  242
#
#
# Updated theta are:  [[340412.65957188]
#  [109446.76268118]
#  [ -6577.3210657 ]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328005e+09]
# Iteration number is:  243
#
#
# Updated theta are:  [[340412.65957214]
#  [109446.80817127]
#  [ -6577.36655578]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328005e+09]
# Iteration number is:  244
#
#
# Updated theta are:  [[340412.65957237]
#  [109446.85165963]
#  [ -6577.41004415]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328005e+09]
# Iteration number is:  245
#
#
# Updated theta are:  [[340412.65957258]
#  [109446.89323437]
#  [ -6577.45161889]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328005e+09]
# Iteration number is:  246
#
#
# Updated theta are:  [[340412.65957277]
#  [109446.93297969]
#  [ -6577.49136421]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328005e+09]
# Iteration number is:  247
#
#
# Updated theta are:  [[340412.65957294]
#  [109446.97097608]
#  [ -6577.5293606 ]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328005e+09]
# Iteration number is:  248
#
#
# Updated theta are:  [[340412.65957309]
#  [109447.0073005 ]
#  [ -6577.56568502]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328005e+09]
# Iteration number is:  249
#
#
# Updated theta are:  [[340412.65957323]
#  [109447.04202653]
#  [ -6577.60041105]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328005e+09]
# Iteration number is:  250
#
#
# Updated theta are:  [[340412.65957335]
#  [109447.0752245 ]
#  [ -6577.63360902]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328005e+09]
# Iteration number is:  251
#
#
# Updated theta are:  [[340412.65957347]
#  [109447.10696165]
#  [ -6577.66534617]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328005e+09]
# Iteration number is:  252
#
#
# Updated theta are:  [[340412.65957357]
#  [109447.13730227]
#  [ -6577.69568679]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328005e+09]
# Iteration number is:  253
#
#
# Updated theta are:  [[340412.65957366]
#  [109447.16630779]
#  [ -6577.72469231]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328005e+09]
# Iteration number is:  254
#
#
# Updated theta are:  [[340412.65957374]
#  [109447.19403698]
#  [ -6577.7524215 ]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328005e+09]
# Iteration number is:  255
#
#
# Updated theta are:  [[340412.65957381]
#  [109447.22054599]
#  [ -6577.77893051]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328005e+09]
# Iteration number is:  256
#
#
# Updated theta are:  [[340412.65957388]
#  [109447.24588852]
#  [ -6577.80427304]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328005e+09]
# Iteration number is:  257
#
#
# Updated theta are:  [[340412.65957394]
#  [109447.2701159 ]
#  [ -6577.82850042]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328005e+09]
# Iteration number is:  258
#
#
# Updated theta are:  [[340412.65957399]
#  [109447.29327719]
#  [ -6577.85166171]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328005e+09]
# Iteration number is:  259
#
#
# Updated theta are:  [[340412.65957404]
#  [109447.31541931]
#  [ -6577.87380383]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328005e+09]
# Iteration number is:  260
#
#
# Updated theta are:  [[340412.65957408]
#  [109447.3365871 ]
#  [ -6577.89497162]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328005e+09]
# Iteration number is:  261
#
#
# Updated theta are:  [[340412.65957412]
#  [109447.35682344]
#  [ -6577.91520796]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328005e+09]
# Iteration number is:  262
#
#
# Updated theta are:  [[340412.65957415]
#  [109447.37616931]
#  [ -6577.93455383]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328005e+09]
# Iteration number is:  263
#
#
# Updated theta are:  [[340412.65957418]
#  [109447.39466391]
#  [ -6577.95304843]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328005e+09]
# Iteration number is:  264
#
#
# Updated theta are:  [[340412.65957421]
#  [109447.41234468]
#  [ -6577.9707292 ]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328005e+09]
# Iteration number is:  265
#
#
# Updated theta are:  [[340412.65957424]
#  [109447.42924744]
#  [ -6577.98763196]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328005e+09]
# Iteration number is:  266
#
#
# Updated theta are:  [[340412.65957426]
#  [109447.44540642]
#  [ -6578.00379094]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328005e+09]
# Iteration number is:  267
#
#
# Updated theta are:  [[340412.65957428]
#  [109447.46085435]
#  [ -6578.01923887]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328005e+09]
# Iteration number is:  268
#
#
# Updated theta are:  [[340412.6595743 ]
#  [109447.47562252]
#  [ -6578.03400704]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328005e+09]
# Iteration number is:  269
#
#
# Updated theta are:  [[340412.65957432]
#  [109447.48974085]
#  [ -6578.04812537]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328005e+09]
# Iteration number is:  270
#
#
# Updated theta are:  [[340412.65957433]
#  [109447.50323792]
#  [ -6578.06162244]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328005e+09]
# Iteration number is:  271
#
#
# Updated theta are:  [[340412.65957435]
#  [109447.51614108]
#  [ -6578.0745256 ]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328005e+09]
# Iteration number is:  272
#
#
# Updated theta are:  [[340412.65957436]
#  [109447.52847646]
#  [ -6578.08686097]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328005e+09]
# Iteration number is:  273
#
#
# Updated theta are:  [[340412.65957437]
#  [109447.54026903]
#  [ -6578.09865355]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328005e+09]
# Iteration number is:  274
#
#
# Updated theta are:  [[340412.65957438]
#  [109447.5515427 ]
#  [ -6578.10992722]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328005e+09]
# Iteration number is:  275
#
#
# Updated theta are:  [[340412.65957439]
#  [109447.56232029]
#  [ -6578.12070481]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328005e+09]
# Iteration number is:  276
#
#
# Updated theta are:  [[340412.6595744 ]
#  [109447.57262363]
#  [ -6578.13100815]]
# Computed cost J_theta for updated theta is:  [2.04328005e+09]
# Iteration number is:  277
#
#
# Updated theta are:  [[340412.6595744 ]
#  [109447.58247359]
#  [ -6578.14085811]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328005e+09]
# Iteration number is:  278
#
#
# Updated theta are:  [[340412.65957441]
#  [109447.59189012]
#  [ -6578.15027464]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328005e+09]
# Iteration number is:  279
#
#
# Updated theta are:  [[340412.65957442]
#  [109447.60089229]
#  [ -6578.15927681]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328005e+09]
# Iteration number is:  280
#
#
# Updated theta are:  [[340412.65957442]
#  [109447.60949833]
#  [ -6578.16788285]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328005e+09]
# Iteration number is:  281
#
#
# Updated theta are:  [[340412.65957443]
#  [109447.61772568]
#  [ -6578.1761102 ]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328005e+09]
# Iteration number is:  282
#
#
# Updated theta are:  [[340412.65957443]
#  [109447.625591  ]
#  [ -6578.18397552]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328005e+09]
# Iteration number is:  283
#
#
# ...
# Iteration number is:  906
#
#
# Updated theta are:  [[340412.65957447]
#  [109447.79646964]
#  [ -6578.35485416]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328005e+09]
# Iteration number is:  907
#
#
# Updated theta are:  [[340412.65957447]
#  [109447.79646964]
#  [ -6578.35485416]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328005e+09]
# Iteration number is:  908
#
#
# Updated theta are:  [[340412.65957447]
#  [109447.79646964]
#  [ -6578.35485416]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328005e+09]
# Iteration number is:  909
#
#
# Updated theta are:  [[340412.65957447]
#  [109447.79646964]
#  [ -6578.35485416]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328005e+09]
# Iteration number is:  910
#
#
# Updated theta are:  [[340412.65957447]
#  [109447.79646964]
#  [ -6578.35485416]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328005e+09]
# Iteration number is:  911
#
#
# Updated theta are:  [[340412.65957447]
#  [109447.79646964]
#  [ -6578.35485416]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328005e+09]
# Iteration number is:  912
#
#
# Updated theta are:  [[340412.65957447]
#  [109447.79646964]
#  [ -6578.35485416]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328005e+09]
# Iteration number is:  913
#
#
# Updated theta are:  [[340412.65957447]
#  [109447.79646964]
#  [ -6578.35485416]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328005e+09]
# Iteration number is:  914
#
#
# Updated theta are:  [[340412.65957447]
#  [109447.79646964]
#  [ -6578.35485416]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328005e+09]
# Iteration number is:  915
#
#
# Updated theta are:  [[340412.65957447]
#  [109447.79646964]
#  [ -6578.35485416]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328005e+09]
# Iteration number is:  916
#
#
# Updated theta are:  [[340412.65957447]
#  [109447.79646964]
#  [ -6578.35485416]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328005e+09]
# Iteration number is:  917
#
#
# Updated theta are:  [[340412.65957447]
#  [109447.79646964]
#  [ -6578.35485416]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328005e+09]
# Iteration number is:  918
#
#
# Updated theta are:  [[340412.65957447]
#  [109447.79646964]
#  [ -6578.35485416]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328005e+09]
# Iteration number is:  919
#
#
# Updated theta are:  [[340412.65957447]
#  [109447.79646964]
#  [ -6578.35485416]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328005e+09]
# Iteration number is:  920
#
#
# Updated theta are:  [[340412.65957447]
#  [109447.79646964]
#  [ -6578.35485416]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328005e+09]
# Iteration number is:  921
#
#
# Updated theta are:  [[340412.65957447]
#  [109447.79646964]
#  [ -6578.35485416]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328005e+09]
# Iteration number is:  922
#
#
# Updated theta are:  [[340412.65957447]
#  [109447.79646964]
#  [ -6578.35485416]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328005e+09]
# Iteration number is:  923
#
#
# Updated theta are:  [[340412.65957447]
#  [109447.79646964]
#  [ -6578.35485416]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328005e+09]
# Iteration number is:  924
#
#
# Updated theta are:  [[340412.65957447]
#  [109447.79646964]
#  [ -6578.35485416]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328005e+09]
# Iteration number is:  925
#
#
# Updated theta are:  [[340412.65957447]
#  [109447.79646964]
#  [ -6578.35485416]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328005e+09]
# Iteration number is:  926
#
#
# Updated theta are:  [[340412.65957447]
#  [109447.79646964]
#  [ -6578.35485416]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328005e+09]
# Iteration number is:  927
#
#
# Updated theta are:  [[340412.65957447]
#  [109447.79646964]
#  [ -6578.35485416]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328005e+09]
# Iteration number is:  928
#
#
# Updated theta are:  [[340412.65957447]
#  [109447.79646964]
#  [ -6578.35485416]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328005e+09]
# Iteration number is:  929
#
#
# Updated theta are:  [[340412.65957447]
#  [109447.79646964]
#  [ -6578.35485416]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328005e+09]
# Iteration number is:  930
#
#
# Updated theta are:  [[340412.65957447]
#  [109447.79646964]
#  [ -6578.35485416]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328005e+09]
# Iteration number is:  931
#
#
# Updated theta are:  [[340412.65957447]
#  [109447.79646964]
#  [ -6578.35485416]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328005e+09]
# Iteration number is:  932
#
#
# Updated theta are:  [[340412.65957447]
#  [109447.79646964]
#  [ -6578.35485416]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328005e+09]
# Iteration number is:  933
#
#
# Updated theta are:  [[340412.65957447]
#  [109447.79646964]
#  [ -6578.35485416]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328005e+09]
# Iteration number is:  934
#
#
# Updated theta are:  [[340412.65957447]
#  [109447.79646964]
#  [ -6578.35485416]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328005e+09]
# Iteration number is:  935
#
#
# Updated theta are:  [[340412.65957447]
#  [109447.79646964]
#  [ -6578.35485416]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328005e+09]
# Iteration number is:  936
#
#
# Updated theta are:  [[340412.65957447]
#  [109447.79646964]
#  [ -6578.35485416]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328005e+09]
# Iteration number is:  937
#
#
# Updated theta are:  [[340412.65957447]
#  [109447.79646964]
#  [ -6578.35485416]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328005e+09]
# Iteration number is:  938
#
#
# Updated theta are:  [[340412.65957447]
#  [109447.79646964]
#  [ -6578.35485416]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328005e+09]
# Iteration number is:  939
#
#
# Updated theta are:  [[340412.65957447]
#  [109447.79646964]
#  [ -6578.35485416]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328005e+09]
# Iteration number is:  940
#
#
# Updated theta are:  [[340412.65957447]
#  [109447.79646964]
#  [ -6578.35485416]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328005e+09]
# Iteration number is:  941
#
#
# Updated theta are:  [[340412.65957447]
#  [109447.79646964]
#  [ -6578.35485416]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328005e+09]
# Iteration number is:  942
#
#
# Updated theta are:  [[340412.65957447]
#  [109447.79646964]
#  [ -6578.35485416]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328005e+09]
# Iteration number is:  943
#
#
# Updated theta are:  [[340412.65957447]
#  [109447.79646964]
#  [ -6578.35485416]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328005e+09]
# Iteration number is:  944
#
#
# Updated theta are:  [[340412.65957447]
#  [109447.79646964]
#  [ -6578.35485416]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328005e+09]
# Iteration number is:  945
#
#
# Updated theta are:  [[340412.65957447]
#  [109447.79646964]
#  [ -6578.35485416]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328005e+09]
# Iteration number is:  946
#
#
# Updated theta are:  [[340412.65957447]
#  [109447.79646964]
#  [ -6578.35485416]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328005e+09]
# Iteration number is:  947
#
#
# Updated theta are:  [[340412.65957447]
#  [109447.79646964]
#  [ -6578.35485416]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328005e+09]
# Iteration number is:  948
#
#
# Updated theta are:  [[340412.65957447]
#  [109447.79646964]
#  [ -6578.35485416]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328005e+09]
# Iteration number is:  949
#
#
# Updated theta are:  [[340412.65957447]
#  [109447.79646964]
#  [ -6578.35485416]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328005e+09]
# Iteration number is:  950
#
#
# Updated theta are:  [[340412.65957447]
#  [109447.79646964]
#  [ -6578.35485416]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328005e+09]
# Iteration number is:  951
#
#
# Updated theta are:  [[340412.65957447]
#  [109447.79646964]
#  [ -6578.35485416]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328005e+09]
# Iteration number is:  952
#
#
# Updated theta are:  [[340412.65957447]
#  [109447.79646964]
#  [ -6578.35485416]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328005e+09]
# Iteration number is:  953
#
#
# Updated theta are:  [[340412.65957447]
#  [109447.79646964]
#  [ -6578.35485416]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328005e+09]
# Iteration number is:  954
#
#
# Updated theta are:  [[340412.65957447]
#  [109447.79646964]
#  [ -6578.35485416]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328005e+09]
# Iteration number is:  955
#
#
# Updated theta are:  [[340412.65957447]
#  [109447.79646964]
#  [ -6578.35485416]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328005e+09]
# Iteration number is:  956
#
#
# Updated theta are:  [[340412.65957447]
#  [109447.79646964]
#  [ -6578.35485416]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328005e+09]
# Iteration number is:  957
#
#
# Updated theta are:  [[340412.65957447]
#  [109447.79646964]
#  [ -6578.35485416]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328005e+09]
# Iteration number is:  958
#
#
# Updated theta are:  [[340412.65957447]
#  [109447.79646964]
#  [ -6578.35485416]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328005e+09]
# Iteration number is:  959
#
#
# Updated theta are:  [[340412.65957447]
#  [109447.79646964]
#  [ -6578.35485416]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328005e+09]
# Iteration number is:  960
#
#
# Updated theta are:  [[340412.65957447]
#  [109447.79646964]
#  [ -6578.35485416]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328005e+09]
# Iteration number is:  961
#
#
# Updated theta are:  [[340412.65957447]
#  [109447.79646964]
#  [ -6578.35485416]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328005e+09]
# Iteration number is:  962
#
#
# Updated theta are:  [[340412.65957447]
#  [109447.79646964]
#  [ -6578.35485416]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328005e+09]
# Iteration number is:  963
#
#
# Updated theta are:  [[340412.65957447]
#  [109447.79646964]
#  [ -6578.35485416]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328005e+09]
# Iteration number is:  964
#
#
# Updated theta are:  [[340412.65957447]
#  [109447.79646964]
#  [ -6578.35485416]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328005e+09]
# Iteration number is:  965
#
#
# Updated theta are:  [[340412.65957447]
#  [109447.79646964]
#  [ -6578.35485416]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328005e+09]
# Iteration number is:  966
#
#
# Updated theta are:  [[340412.65957447]
#  [109447.79646964]
#  [ -6578.35485416]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328005e+09]
# Iteration number is:  967
#
#
# Updated theta are:  [[340412.65957447]
#  [109447.79646964]
#  [ -6578.35485416]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328005e+09]
# Iteration number is:  968
#
#
# Updated theta are:  [[340412.65957447]
#  [109447.79646964]
#  [ -6578.35485416]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328005e+09]
# Iteration number is:  969
#
#
# Updated theta are:  [[340412.65957447]
#  [109447.79646964]
#  [ -6578.35485416]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328005e+09]
# Iteration number is:  970
#
#
# Updated theta are:  [[340412.65957447]
#  [109447.79646964]
#  [ -6578.35485416]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328005e+09]
# Iteration number is:  971
#
#
# Updated theta are:  [[340412.65957447]
#  [109447.79646964]
#  [ -6578.35485416]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328005e+09]
# Iteration number is:  972
#
#
# Updated theta are:  [[340412.65957447]
#  [109447.79646964]
#  [ -6578.35485416]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328005e+09]
# Iteration number is:  973
#
#
# Updated theta are:  [[340412.65957447]
#  [109447.79646964]
#  [ -6578.35485416]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328005e+09]
# Iteration number is:  974
#
#
# Updated theta are:  [[340412.65957447]
#  [109447.79646964]
#  [ -6578.35485416]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328005e+09]
# Iteration number is:  975
#
#
# Updated theta are:  [[340412.65957447]
#  [109447.79646964]
#  [ -6578.35485416]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328005e+09]
# Iteration number is:  976
#
#
# Updated theta are:  [[340412.65957447]
#  [109447.79646964]
#  [ -6578.35485416]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328005e+09]
# Iteration number is:  977
#
#
# Updated theta are:  [[340412.65957447]
#  [109447.79646964]
#  [ -6578.35485416]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328005e+09]
# Iteration number is:  978
#
#
# Updated theta are:  [[340412.65957447]
#  [109447.79646964]
#  [ -6578.35485416]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328005e+09]
# Iteration number is:  979
#
#
# Updated theta are:  [[340412.65957447]
#  [109447.79646964]
#  [ -6578.35485416]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328005e+09]
# Iteration number is:  980
#
#
# Updated theta are:  [[340412.65957447]
#  [109447.79646964]
#  [ -6578.35485416]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328005e+09]
# Iteration number is:  981
#
#
# Updated theta are:  [[340412.65957447]
#  [109447.79646964]
#  [ -6578.35485416]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328005e+09]
# Iteration number is:  982
#
#
# Updated theta are:  [[340412.65957447]
#  [109447.79646964]
#  [ -6578.35485416]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328005e+09]
# Iteration number is:  983
#
#
# Updated theta are:  [[340412.65957447]
#  [109447.79646964]
#  [ -6578.35485416]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328005e+09]
# Iteration number is:  984
#
#
# Updated theta are:  [[340412.65957447]
#  [109447.79646964]
#  [ -6578.35485416]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328005e+09]
# Iteration number is:  985
#
#
# Updated theta are:  [[340412.65957447]
#  [109447.79646964]
#  [ -6578.35485416]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328005e+09]
# Iteration number is:  986
#
#
# Updated theta are:  [[340412.65957447]
#  [109447.79646964]
#  [ -6578.35485416]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328005e+09]
# Iteration number is:  987
#
#
# Updated theta are:  [[340412.65957447]
#  [109447.79646964]
#  [ -6578.35485416]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328005e+09]
# Iteration number is:  988
#
#
# Updated theta are:  [[340412.65957447]
#  [109447.79646964]
#  [ -6578.35485416]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328005e+09]
# Iteration number is:  989
#
#
# Updated theta are:  [[340412.65957447]
#  [109447.79646964]
#  [ -6578.35485416]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328005e+09]
# Iteration number is:  990
#
#
# Updated theta are:  [[340412.65957447]
#  [109447.79646964]
#  [ -6578.35485416]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328005e+09]
# Iteration number is:  991
#
#
# Updated theta are:  [[340412.65957447]
#  [109447.79646964]
#  [ -6578.35485416]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328005e+09]
# Iteration number is:  992
#
#
# Updated theta are:  [[340412.65957447]
#  [109447.79646964]
#  [ -6578.35485416]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328005e+09]
# Iteration number is:  993
#
#
# Updated theta are:  [[340412.65957447]
#  [109447.79646964]
#  [ -6578.35485416]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328005e+09]
# Iteration number is:  994
#
#
# Updated theta are:  [[340412.65957447]
#  [109447.79646964]
#  [ -6578.35485416]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328005e+09]
# Iteration number is:  995
#
#
# Updated theta are:  [[340412.65957447]
#  [109447.79646964]
#  [ -6578.35485416]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328005e+09]
# Iteration number is:  996
#
#
# Updated theta are:  [[340412.65957447]
#  [109447.79646964]
#  [ -6578.35485416]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328005e+09]
# Iteration number is:  997
#
#
# Updated theta are:  [[340412.65957447]
#  [109447.79646964]
#  [ -6578.35485416]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328005e+09]
# Iteration number is:  998
#
#
# Updated theta are:  [[340412.65957447]
#  [109447.79646964]
#  [ -6578.35485416]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328005e+09]
# Iteration number is:  999
#
#
# Updated theta are:  [[340412.65957447]
#  [109447.79646964]
#  [ -6578.35485416]]
#
#
# Computed cost J_theta for updated theta is:  [2.04328005e+09]
# 2043280050.6028287

# %%
plt.plot(range(iters), cost)

plt.xlabel('Iterations')
plt.ylabel('Cost')

plt.title('Plot of Cost vs Iterations')

plt.show()

# %%
# Predicting price based on computed theta
# (estimating yi for given Xi)

# Estimate the price of a 1650 sq-ft, 3 br house
# the first column of X is all-ones. It does not need to be normalized.

Xi = np.matrix(np.array([1, 1650, 3]))               # Xi = [1, 1650, 3]

price = Xi * theta

print(Xi)
print(theta)
print('price = ', price)
# Out:
# [[   1 1650    3]]
# [[340412.65957447]
#  [109447.79646964]
#  [ -6578.35485416]]
# price =  [[1.80909542e+08]]
